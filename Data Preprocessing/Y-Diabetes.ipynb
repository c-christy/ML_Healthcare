# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

#plasma_glucose= pd.read_sas('GLU_H.XPT')
plasma_glucose= pd.read_sas('GLU_I.XPT')

# %%
plasma=plasma_glucose[['SEQN','LBXGLU']]

# %%
plasma=plasma.dropna()

# %%
#plasma=plasma['LBXGLU']

# %%
plasma.loc[(plasma.LBXGLU<=126),"LBXGLU"]=0

# %%
plasma.loc[(plasma.LBXGLU>126),"LBXGLU"]=1

# %%
plasma
# Out:
#          SEQN  LBXGLU
# 0     83733.0     0.0
# 1     83734.0     0.0
# 2     83736.0     0.0
# 3     83737.0     0.0
# 4     83741.0     0.0
# 5     83743.0     0.0
# 6     83749.0     0.0
# 7     83750.0     0.0
# 8     83753.0     0.0
# 9     83754.0     1.0
# 10    83755.0     1.0
# 11    83757.0     1.0
# 12    83761.0     0.0
# 13    83764.0     1.0
# 14    83770.0     0.0
# 15    83773.0     0.0
# 16    83777.0     1.0
# 17    83778.0     0.0
# 18    83781.0     0.0
# 20    83787.0     0.0
# 21    83789.0     0.0
# 22    83790.0     1.0
# 23    83799.0     0.0
# 24    83801.0     0.0
# 25    83809.0     0.0
# 26    83813.0     0.0
# 27    83815.0     0.0
# 28    83816.0     0.0
# 29    83818.0     0.0
# 30    83820.0     0.0
# ...       ...     ...
# 3158  93577.0     0.0
# 3159  93582.0     0.0
# 3160  93589.0     0.0
# 3161  93590.0     0.0
# 3163  93592.0     0.0
# 3164  93593.0     0.0
# 3165  93595.0     0.0
# 3166  93598.0     0.0
# 3167  93600.0     0.0
# ...

# %%
plasma.to_csv('diabetes_1516.csv',index=True)
