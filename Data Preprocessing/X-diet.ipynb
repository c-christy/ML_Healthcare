# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
diet1314 = pd.read_sas('DBQ_H.XPT')
diet1516 = pd.read_sas('DBQ_I.XPT')

# %%
diet1314 = diet1314.iloc[:,[0,13,14,15,16,21,22,23,24,35,36,37,38,42,43,46,47,48]]
diet1516 = diet1516.iloc[:,[0,13,14,15,16,21,22,23,24,35,36,37,38,42,43,46,47,48]]

# %%
diet1314.DBQ700 = diet1314.DBQ700.fillna(10)
diet1516.DBQ700 = diet1516.DBQ700.fillna(10)

# %%
diet1314.DBQ197 = diet1314.DBQ197.fillna(10)
diet1516.DBQ197 = diet1516.DBQ197.fillna(10)

# %%
diet1314.DBQ223A = diet1314.DBQ223A.fillna(100)
diet1516.DBQ223A = diet1516.DBQ223A.fillna(100)

# %%
diet1314.DBQ223B = diet1314.DBQ223B.fillna(12)
diet1516.DBQ223B = diet1516.DBQ223B.fillna(12)

# %%
diet1314.DBQ229 = diet1314.DBQ229.fillna(10)
diet1516.DBQ229 = diet1516.DBQ229.fillna(10)

# %%
diet1314.DBQ235A = diet1314.DBQ235A.fillna(10)
diet1516.DBQ235A = diet1516.DBQ235A.fillna(10)

# %%
diet1314.DBQ235B = diet1314.DBQ235B.fillna(10)
diet1516.DBQ235B = diet1516.DBQ235B.fillna(10)

# %%
diet1314.DBQ235C = diet1314.DBQ235C.fillna(10)
diet1516.DBQ235C = diet1516.DBQ235C.fillna(10)

# %%
diet1314['Missing_DBD895'] = 0
diet1516['Missing_DBD895'] = 0

# %%
diet1314.loc[(diet1314.DBD895.isnull()), 'Missing_DBD895'] = 1
diet1516.loc[(diet1516.DBD895.isnull()), 'Missing_DBD895'] = 1

# %%
diet1314.DBD895 = diet1314.DBD895.fillna(0)
diet1516.DBD895 = diet1516.DBD895.fillna(0)

# %%
diet1314.loc[(diet1314.DBD895 == 5555), 'DBD895'] = 22
diet1516.loc[(diet1516.DBD895 == 5555), 'DBD895'] = 22

# %%
diet1314.loc[(diet1314.DBD895 == 7777)|(diet1314.DBD895 == 9999), 'DBD895'] = 0
diet1516.loc[(diet1516.DBD895 == 7777)|(diet1516.DBD895 == 9999), 'DBD895'] = 0

# %%
diet1314['Missing_DBD900'] = 0
diet1516['Missing_DBD900'] = 0

# %%
diet1314.loc[(diet1314.DBD900.isnull()), 'Missing_DBD900'] = 1
diet1516.loc[(diet1516.DBD900.isnull()), 'Missing_DBD900'] = 1

# %%
diet1314.DBD900 = diet1314.DBD900.fillna(0)
diet1516.DBD900 = diet1516.DBD900.fillna(0)

# %%
diet1314.loc[(diet1314.DBD900 == 5555), 'DBD900'] = 22
diet1516.loc[(diet1516.DBD900 == 5555), 'DBD900'] = 22

# %%
diet1314.loc[(diet1314.DBD900 == 7777)|(diet1314.DBD900 == 9999), 'DBD900'] = 0
diet1516.loc[(diet1516.DBD900 == 7777)|(diet1516.DBD900 == 9999), 'DBD900'] = 0

# %%
diet1314['Missing_DBD905'] = 0
diet1516['Missing_DBD905'] = 0

# %%
diet1314.loc[(diet1314.DBD905.isnull()), 'Missing_DBD905'] = 1
diet1516.loc[(diet1516.DBD905.isnull()), 'Missing_DBD905'] = 1

# %%
diet1314.DBD905 = diet1314.DBD905.fillna(0)
diet1516.DBD905 = diet1516.DBD905.fillna(0)

# %%
diet1314.loc[(diet1314.DBD905 == 7777)|(diet1314.DBD905 == 9999), 'DBD905'] = 0
diet1516.loc[(diet1516.DBD905 == 7777)|(diet1516.DBD905 == 9999), 'DBD905'] = 0

# %%
diet1314['Missing_DBD910'] = 0
diet1516['Missing_DBD910'] = 0

# %%
diet1314.loc[(diet1314.DBD910.isnull()), 'Missing_DBD910'] = 1
diet1516.loc[(diet1516.DBD910.isnull()), 'Missing_DBD910'] = 1

# %%
diet1314.DBD910 = diet1314.DBD910.fillna(0)
diet1516.DBD910 = diet1516.DBD910.fillna(0)

# %%
diet1314.loc[(diet1314.DBD910 == 7777)|(diet1314.DBD910 == 9999), 'DBD910'] = 0
diet1516.loc[(diet1516.DBD910 == 7777)|(diet1516.DBD910 == 9999), 'DBD910'] = 0

# %%
diet1314.CBQ505 = diet1314.CBQ505.fillna(10)
diet1516.CBQ505 = diet1516.CBQ505.fillna(10)

# %%
diet1314.CBQ535 = diet1314.CBQ535.fillna(10)
diet1516.CBQ535 = diet1516.CBQ535.fillna(10)

# %%
diet1314.CBQ550 = diet1314.CBQ550.fillna(10)
diet1516.CBQ550 = diet1516.CBQ550.fillna(10)

# %%
diet1314.CBQ552 = diet1314.CBQ552.fillna(10)
diet1516.CBQ552 = diet1516.CBQ552.fillna(10)

# %%
diet1314.CBQ580 = diet1314.CBQ580.fillna(10)
diet1516.CBQ580 = diet1516.CBQ580.fillna(10)

# %%
diet1314.to_csv(r'/Users/aimeechen/Desktop/Berkeley/capstone/capstone/diet/1314/Diet1314.csv', index=False)
diet1516.to_csv(r'/Users/aimeechen/Desktop/Berkeley/capstone/capstone/diet/1516/Diet1516.csv', index=False)

# %%
diet1314.hist(figsize=(19,16))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x124a8ea90>,
# ...
#       dtype=object)
